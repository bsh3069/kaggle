# %% [markdown]
# # 라이브러리

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 데이터 불러오기

# %%
train = pd.read_csv('C:/Users/bsh36/Desktop/Data/sf/train.csv')
test = pd.read_csv('C:/Users/bsh36/Desktop/Data/sf/test.csv')
sub = pd.read_csv('C:/Users/bsh36/Desktop/Data/sf/sampleSubmission.csv')

# %%
train.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# ...

# %%
test.head()
# Out:
#    Id                Dates DayOfWeek PdDistrict                   Address  \
# 0   0  2015-05-10 23:59:00    Sunday    BAYVIEW   2000 Block of THOMAS AV
# 1   1  2015-05-10 23:51:00    Sunday    BAYVIEW        3RD ST / REVERE AV
# 2   2  2015-05-10 23:50:00    Sunday   NORTHERN    2000 Block of GOUGH ST
# 3   3  2015-05-10 23:45:00    Sunday  INGLESIDE  4700 Block of MISSION ST
# 4   4  2015-05-10 23:45:00    Sunday  INGLESIDE  4700 Block of MISSION ST
#
#             X          Y
# 0 -122.399588  37.735051
# 1 -122.391523  37.732432
# 2 -122.426002  37.792212
# 3 -122.437394  37.721412
# 4 -122.437394  37.721412

# %%
train.Category.value_counts()
# Out:
# LARCENY/THEFT                  174900
# OTHER OFFENSES                 126182
# NON-CRIMINAL                    92304
# ASSAULT                         76876
# DRUG/NARCOTIC                   53971
# VEHICLE THEFT                   53781
# VANDALISM                       44725
# WARRANTS                        42214
# BURGLARY                        36755
# SUSPICIOUS OCC                  31414
# MISSING PERSON                  25989
# ROBBERY                         23000
# FRAUD                           16679
# FORGERY/COUNTERFEITING          10609
# SECONDARY CODES                  9985
# WEAPON LAWS                      8555
# PROSTITUTION                     7484
# TRESPASS                         7326
# STOLEN PROPERTY                  4540
# SEX OFFENSES FORCIBLE            4388
# DISORDERLY CONDUCT               4320
# DRUNKENNESS                      4280
# RECOVERED VEHICLE                3138
# KIDNAPPING                       2341
# DRIVING UNDER THE INFLUENCE      2268
# ...

# %%
alldata = pd.concat([train,test])
alldata
# Out:
#                       Dates        Category                      Descript  \
# 0       2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1       2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2       2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3       2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4       2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# ...                     ...             ...                           ...
# 884257  2003-01-01 00:01:00             NaN                           NaN
# 884258  2003-01-01 00:01:00             NaN                           NaN
# 884259  2003-01-01 00:01:00             NaN                           NaN
# 884260  2003-01-01 00:01:00             NaN                           NaN
# 884261  2003-01-01 00:01:00             NaN                           NaN
#
#         DayOfWeek PdDistrict      Resolution                      Address  \
# ...

# %% [markdown]
# # 전처리

# %%
alldata['Dates'] = pd.to_datetime(alldata['Dates'])
alldata['Year'] = alldata['Dates'].dt.year
alldata['Month'] = alldata['Dates'].dt.month
alldata['Week'] = alldata['Dates'].dt.week
alldata['Day'] = alldata['Dates'].dt.day
alldata['Hour'] = alldata['Dates'].dt.hour
alldata['Minute'] = alldata['Dates'].dt.minute
# Out:
# c:\anaconda3\envs\project\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   after removing the cwd from sys.path.

# %%
alldata['time'] = alldata['Dates'].dt.date - alldata['Dates'].dt.date.min()
alldata['time'] = alldata['time'].apply(lambda x : x.days)
alldata.time
# Out:
# 0         4515
# 1         4515
# 2         4515
# 3         4515
# 4         4515
#           ...
# 884257       0
# 884258       0
# 884259       0
# 884260       0
# 884261       0
# Name: time, Length: 1762311, dtype: int64

# %%
alldata2 = alldata.drop(columns = ['Dates','Category','Id','Descript','Resolution'])
alldata2
# Out:
#         DayOfWeek PdDistrict                      Address           X  \
# 0       Wednesday   NORTHERN           OAK ST / LAGUNA ST -122.425892
# 1       Wednesday   NORTHERN           OAK ST / LAGUNA ST -122.425892
# 2       Wednesday   NORTHERN    VANNESS AV / GREENWICH ST -122.424363
# 3       Wednesday   NORTHERN     1500 Block of LOMBARD ST -122.426995
# 4       Wednesday       PARK    100 Block of BRODERICK ST -122.438738
# ...           ...        ...                          ...         ...
# 884257  Wednesday    MISSION      2600 Block of BRYANT ST -122.408983
# 884258  Wednesday   NORTHERN  1900 Block of WASHINGTON ST -122.425342
# 884259  Wednesday  INGLESIDE     5500 Block of MISSION ST -122.445418
# 884260  Wednesday    BAYVIEW      1500 Block of HUDSON AV -122.387394
# 884261  Wednesday    TARAVAL       1500 Block of SLOAT BL -122.489714
#
#                 Y  Year  Month  Week  Day  Hour  Minute  time
# 0       37.774599  2015      5    20   13    23      53  4515
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
c = alldata2.columns[alldata2.dtypes==object]
for i in c:
    alldata2[i] = le.fit_transform(alldata2[i])
alldata2
# Out:
#         DayOfWeek  PdDistrict  Address           X          Y  Year  Month  \
# 0               6           4    20895 -122.425892  37.774599  2015      5
# 1               6           4    20895 -122.425892  37.774599  2015      5
# 2               6           4    24169 -122.424363  37.800414  2015      5
# 3               6           4     4418 -122.426995  37.800873  2015      5
# 4               6           5     1923 -122.438738  37.771541  2015      5
# ...           ...         ...      ...         ...        ...   ...    ...
# 884257          6           3     7919 -122.408983  37.751987  2003      1
# 884258          6           4     5596 -122.425342  37.792681  2003      1
# 884259          6           2    11612 -122.445418  37.712075  2003      1
# 884260          6           0     4393 -122.387394  37.739479  2003      1
# 884261          6           8     4476 -122.489714  37.733950  2003      1
#
#         Week  Day  Hour  Minute  time
# ...

# %%
train2 = alldata2[:len(train)]
test2 = alldata2[len(train):]

# %%
from sklearn.model_selection import train_test_split
x_train, x_valid, y_train, y_valid = train_test_split(train2, train['Category'],test_size=0.2,random_state=1,
                                                      stratify=train['Category'])

# %%
from catboost import CatBoostClassifier
cbc = CatBoostClassifier(verbose=100)

# %%
cbc.fit(x_train, y_train, eval_set=(x_valid, y_valid))

# %%
result = cbc.predict_proba(test2)
result

# %%
sub.iloc[:,1:] = result
sub

# %%
sub.to_csv('C:/Users/bsh36/Desktop/Data/sf/cbc.csv',index=False)
